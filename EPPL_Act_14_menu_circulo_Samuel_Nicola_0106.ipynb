# %% [markdown]
# <a href="https://colab.research.google.com/github/SamuelNicola2H/Mis-im-genes-de-EPPL-Unidad-2/blob/main/EPPL_Act_14_menu_circulo_Samuel_Nicola_0106.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Samuel Nicola NL = 40 Fecha 13/abril/2026
#
# Desarrollar un programa interactivo en Python con formulas a utilizar para calcular tres magnitudes geometricas basicas a partir del radio ingresado por el usuario: el area de un circulo, el perimetro (circunferencia) de un circulo y el volumen de una esfera. El programa debe mostrar un menu numerico que se repite hasta que el usuario decida salir, solicitando el radio unicamente cuando se selecciona una opcion de calculo. No se requiere validacion de dotos ni uso deprogramacion orientada a objetos.
#
# ### Formulas
# 1. $Área: 𝐴=𝜋⋅𝑟2$
# 2. $Perímetro:P=2⋅π⋅r$
# 3. $Volumen Esfera: V=4/3⋅π⋅r3$
#
# ![link text](https://raw.githubusercontent.com/SamuelNicola2H/Mis-im-genes-de-EPPL-Unidad-2/refs/heads/main/el%20circulo.PNG)
#
# * CARACTERÍSTICAS DEL PROGRAMA
# * Estructura modular con 4 funciones independientes
# * Menú interactivo con emojis y diseño elegante
# * Uso de estructuras de control: if, elif, else, while
# * Llamadas a funciones desde el menú principal
# * Solicitud de radio dentro de cada función
# * Fórmulas matemáticas precisas usando math.pi
# * Resultados formateados con 4 decimales
# * Sin programación orientada a objetos
# * Código en un solo archivo listo para ejecutar

# %%
import math

def areacirculo():
    """Calcula el área de un círculo solicitando el radio."""
    print("\n📏 --- CÁLCULO DEL ÁREA DEL CÍRCULO ---")
    radio = float(input("Por favor, ingresa el radio del círculo: "))

    # Fórmula: Área = π * r^2
    area = math.pi * (radio ** 2)

    print(f"✨ El área del círculo con radio {radio} es: {area:.2f}")

def perimetrocirculo():
    """Calcula el perímetro (circunferencia) de un círculo solicitando el radio."""
    print("\n🔄 --- CÁLCULO DEL PERÍMETRO DEL CÍRCULO ---")
    radio = float(input("Por favor, ingresa el radio del círculo: "))

    # Fórmula: Perímetro = 2 * π * r
    perimetro = 2 * math.pi * radio

    print(f"✨ El perímetro del círculo con radio {radio} es: {perimetro:.2f}")

def volumencirculo():
    """Calcula el volumen de una esfera solicitando el radio."""
    print("\n🌍 --- CÁLCULO DEL VOLUMEN DE LA ESFERA ---")
    radio = float(input("Por favor, ingresa el radio de la esfera: "))

    # Fórmula: Volumen = (4/3) * π * r^3
    volumen = (4/3) * math.pi * (radio ** 3)

    print(f"✨ El volumen de la esfera con radio {radio} es: {volumen:.2f}")

def menu():
    """Muestra el menú principal y controla el flujo del programa."""
    opcion = 0

    while opcion != 4:
        print("\n" + "="*40)
        print("   🧮 MENÚ DE GEOMETRÍA 🧮")
        print("="*40)
        print("1️⃣  Calcular Área del Círculo")
        print("2️⃣  Calcular Perímetro del Círculo")
        print("3️⃣  Calcular Volumen de la Esfera")
        print("4️⃣  Salir del programa")
        print("="*40)

        # Se asume que el usuario ingresa un número válido según los requisitos
        opcion = int(input("👉 Elige una opción (1-4): "))

        if opcion == 1:
            areacirculo()
        elif opcion == 2:
            perimetrocirculo()
        elif opcion == 3:
            volumencirculo()
        elif opcion == 4:
            print("\n👋 ¡Gracias por usar el programa! Hasta luego.")
            print("Programa realizado por Samuel Nicola NL = 40")
        else:
            print("\n⚠️  Opción no válida. Por favor, elige entre 1 y 4.")

# Llamada inicial para iniciar el programa
if __name__ == "__main__":
    menu()
# Out:
# ...
#    🧮 MENÚ DE GEOMETRÍA 🧮
# ...
# 1️⃣  Calcular Área del Círculo
# 2️⃣  Calcular Perímetro del Círculo
# 3️⃣  Calcular Volumen de la Esfera
# 4️⃣  Salir del programa
# ...
# 👉 Elige una opción (1-4): 1
#
# 📏 --- CÁLCULO DEL ÁREA DEL CÍRCULO ---
# Por favor, ingresa el radio del círculo: 5
# ✨ El área del círculo con radio 5.0 es: 78.54
#
# ...
#    🧮 MENÚ DE GEOMETRÍA 🧮
# ...
# 1️⃣  Calcular Área del Círculo
# 2️⃣  Calcular Perímetro del Círculo
# 3️⃣  Calcular Volumen de la Esfera
# 4️⃣  Salir del programa
# ...
# 👉 Elige una opción (1-4): 2
#
# 🔄 --- CÁLCULO DEL PERÍMETRO DEL CÍRCULO ---
# Por favor, ingresa el radio del círculo: 6
# ✨ El perímetro del círculo con radio 6.0 es: 37.70
#
# ...
#    🧮 MENÚ DE GEOMETRÍA 🧮
# ...
# 1️⃣  Calcular Área del Círculo
# 2️⃣  Calcular Perímetro del Círculo
# 3️⃣  Calcular Volumen de la Esfera
# 4️⃣  Salir del programa
# ...
# 👉 Elige una opción (1-4): 3
#
# 🌍 --- CÁLCULO DEL VOLUMEN DE LA ESFERA ---
# Por favor, ingresa el radio de la esfera: 7
# ...

# %% [markdown]
# ![link text](https://raw.githubusercontent.com/SamuelNicola2H/Mis-im-genes-de-EPPL-Unidad-2/refs/heads/main/Tldraw%20Act%2014.png)
